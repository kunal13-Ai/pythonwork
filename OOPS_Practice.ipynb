# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal13-Ai/pythonwork/blob/main/OOPS_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_nums(a,b):
  sum_nums=a+b
  return sum_nums

# %%
add_nums(5,8)
# Out:
# 13

# %%
class calculator :
  def __init__(self):
    pass

  def add_nums(self,a,b):
    sum_nums=a+b
    return sum_nums

  def sub_nums(self,a,b):
    sub_nums=a-b
    return sub_nums

  def mult_nums(self,a,b):
     a*b
     return  a*b

  def div_nums(self,a,b):
     a/b
     return a/b

# %%
c=calculator()

# %%
c=calculator() # Re-initialize the calculator object
print(c.add_nums(9,5))
print(c.sub_nums(9,5))
print(c.mult_nums(9,5))
print(c.div_nums(9,5))
# Out:
# 14
# 4
# 45
# 1.8

# %% [markdown]
# ## ATM

# %%
class Atm :

  # constructor
  def __init__(self,owner, balance=0):
    self.pin     = ''
    self.balance = balance
    self.owner = owner
    self.menu()

  def menu(self):
    user_input = input("""
    hi, can I help you?
    1. press 1 to change pin
    2. press 2 to create pin
    3. press 3 to check balance
    4. press 4 to withdraw money
    5. press 5 to deposit money
    6. anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
      pass
    elif user_input == '2':
      self.change_pin()
      pass
    elif user_input == '3':
      self.check_bal()
      pass
    elif user_input =='4' :
      self.withdraw()
      pass
    elif user_input == '5':
      self.deposit()
      pass
    else:
      exit()
      print("Thank you , please visit again")

  def create_pin(self):
   user_pin = input("enter your pin")
   self.pin = user_pin
   print('pin created sucessfully')
   self.menu()

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin :
     new_pin = input('enter new pin')
     self.pin = new_pin
     print('pin change sucsseful')

    else :
      print('wrong , enter correct pin')
    self.menu()

  def check_bal(self):
    user_pin = input('enter your pin')

    if user_pin == self.pin :
      print('your balance is', self.balance)

    else :
      print('wrong pin, please enter correct pin')
    self.menu()

  def withdraw(self):
    user_pin = input('enter your pin')

    if user_pin == self.pin :
      amount = int(input('enter amount'))

      if amount <= self.balance :
       self.balance = self.balance - amount
       print('withdraw sucsessful')
       print('After withdraw',amount,'your remaining balance is',self.balance)

      else:
        print('Insufficient balance')

    else :
      print('Wrong pin please enter correct pin')
    self.menu()

  def deposit(self):
    user_pin = input('enter your pin ')
    if user_pin == self.pin :
      amount = int(input('enter amount for deposit'))
      self.balance =+ amount
      print('After deposit your balance is',self.balance)
      self.menu()
    else :
      print('sorry')
    self.menu()

# %%
account01=Atm('kunal')
# Out:
#     hi, can I help you?
#     1. press 1 to change pin
#     2. press 2 to create pin
#     3. press 3 to check balance
#     4. press 4 to withdraw money
#     5. press 5 to deposit money
#     6. anything else to exit
#     6
# Thank you , please visit again

# %% [markdown]
# # Banking Withdraw and deposit

# %%
# for deposit
def deposit(balance,amount):
 balance = balance + amount
 print('After deposit',amount,' your balance is',balance)
 return balance

# for withdraw
def withdraw(balance,amount):
 if amount <= balance :
  balance = balance - amount
  print('After withdrawing',amount , 'your  balance is ',balance)
 else :
  print('Insufficient balance')
 return balance

def show_balance(balance):
  print('your finanl balance is ',balance)

# %%
balance=0
balance=deposit(balance,1000)
balance=deposit(balance,3000)
balance=withdraw(balance,2500)
balance=deposit(balance,1700)
balance=withdraw(balance,3900)
balance=deposit(balance,300)
show_balance(balance)
# Out:
# After deposit 1000  your balance is 1000
# After deposit 3000  your balance is 4000
# After withdrawing 2500 your  balance is  1500
# After deposit 1700  your balance is 3200
# Insufficient balance
# After deposit 300  your balance is 3500
# your finanl balance is  3500

# %%
# using class constructor

class BankAccount :

   def __init__(self,owner,balance=0):
    self.owner = owner
    self.balance = balance

   def deposit(self , amount):
    self.balance = self.balance + amount
    print('After deposit',amount,'your balance is',self.balance)
    return self.balance

   def withdraw(self , amount):
    if amount <= self.balance :
      self.balance = self.balance - amount
      print('After withdrawal',amount,'your balance is',self.balance)
      return self.balance
    else:
      print("Insufficient balance",self.balance)

    def show_bal(self,amount):
      return self.balance
      print("Your final balance is ",self.balance)

# %%
account3 = BankAccount('Kunal')
account2 = BankAccount('Nikhil',2500)

# %%
account3.deposit(5000)
account3.deposit(1500)
account3.withdraw(3300)
account3.deposit(7000)
account3.withdraw(9500)
# Out:
# After deposit 5000 your balance is 5000
# After deposit 1500 your balance is 6500
# After withdrawal 3300 your balance is 3200
# After deposit 7000 your balance is 10200
# After withdrawal 9500 your balance is 700
# 700

# %%
account2.deposit(5000)
account2.deposit(1500)
account2.withdraw(3300)
account2.deposit(7000)
account2.withdraw(9500)
# Out:
# After deposit 5000 your balance is 7500
# After deposit 1500 your balance is 9000
# After withdrawal 3300 your balance is 5700
# After deposit 7000 your balance is 12700
# After withdrawal 9500 your balance is 3200
# 3200

# %% [markdown]
# ## Encapsulation (private)

# %%
class Atm :

  # constructor
  def __init__(self):
    print(id(self))
    self.pin     = ''
    self.__balance = 0  # we make object private by __ double underscore

  def get_balance(self): # this is getter it's READ CONTROL
    return self.__balance

  def set_balance(self , new_balance): # this is setter it's WRITE CONTOL
   if type(new_balance) == int :
    self.__balance = new_balance
   else:
    print('not allowed')
    #self.menu()

  def menu(self):
    user_input = input("""
    hi, can I help you?
    1. press 1 to change pin
    2. press 2 to create pin
    3. press 3 to check balance
    4. press 4 to withdraw money
    5. press 5 to deposit money
    6. anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
      pass
    elif user_input == '2':
      self.change_pin()
      pass
    elif user_input == '3':
      self.check_bal()
      pass
    elif user_input =='4' :
      self.withdraw()
      pass
    elif user_input == '5':
      self.deposit()
      pass
    else:
      exit()
      print("Thank you , please visit again")

  def create_pin(self):
   user_pin = input("enter your pin")
   self.pin = user_pin
   print('pin created sucessfully')
   self.menu()

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin :
     new_pin = input('enter new pin')
     self.pin = new_pin
     print('pin change sucsseful')

    else :
      print('wrong , enter correct pin')
    self.menu()

  def check_bal(self):
    user_pin = input('enter your pin')

    if user_pin == self.pin :
      print('your balance is', self.__balance)

    else :
      print('wrong pin, please enter correct pin')
    self.menu()

  def withdraw(self):
    user_pin = input('enter your pin')

    if user_pin == self.pin :
      amount = int(input('enter amount'))

      if amount <= self.__balance :
       self.__balance = self.__balance - amount
       print('withdraw sucsessful')
       print('After withdraw',amount,'your remaining balance is',self.__balance)

      else:
        print('Insufficient balance')

    else :
      print('Wrong pin please enter correct pin')
    self.menu()

  def deposit(self):
    user_pin = input('enter your pin ')
    if user_pin == self.pin :
      amount = int(input('enter amount for deposit'))
      self.__balance =+ amount
      print('After deposit your balance is',self.__balance)
      self.menu()
    else :
      print('sorry')
    self.menu()

# %%
obj = Atm()
# Out:
# 136323250717664

# %%
obj.balance = 'hehehe'
id(obj.balance)
# Out:
# 136323250718400

# %%
obj.__balance = 'hehehe'
id(obj.__balance)
# Out:
# 136323250718400

# %%
obj.get_balance()  # old balance
# Out:
# 0

# %%
obj.set_balance(100) # setting new balance

# %%
obj.get_balance()  # new balance
# Out:
# 100

# %%
obj.withdraw()
# Out:
# enter your pin1234
# Wrong pin please enter correct pin
#
#     hi, can I help you?
#     1. press 1 to change pin
#     2. press 2 to create pin
#     3. press 3 to check balance
#     4. press 4 to withdraw money
#     5. press 5 to deposit money
#     6. anything else to exit
#     4
# enter your pin
# enter amount6
# withdraw sucsessful
# After withdraw 6 your remaining balance is 94
#
#     hi, can I help you?
#     1. press 1 to change pin
#     2. press 2 to create pin
#     3. press 3 to check balance
#     4. press 4 to withdraw money
#     5. press 5 to deposit money
#     6. anything else to exit
#     6
# Thank you , please visit again
