# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal13-Ai/pythonwork/blob/main/Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = {
    "EmpID": [101,102,103,104,105,106,107,108,109,110,111,112],
    "Name": ["Arjun","Meera","Ravi","Sana","Kiran","Divya","Mohan","Priya","Amit","Neha","Farhan","Isha"],
    "Dept": ["DataSci","ML","DataEng","DataSci","DevOps","ML","DataEng","DevOps","DataSci","ML","DevOps","DataEng"],
    "Salary": [82000,95000,76000,88000,70000, np.nan, 81000,69000,92000,84000,71000,78500],
    "Experience": [3,5,2,4,1,3,5,2,6,3,1,2],
    "City": ["Bangalore","Mumbai","Pune","Delhi","Hyderabad","Bangalore","Chennai","Mumbai","Pune","Delhi","Bangalore","Hyderabad"],
    "Age": [26,29,24,28,np.nan,27,30,23,31,np.nan,22,25],
    "Performance": [4.3,4.8,3.9,np.nan,3.7,4.1,4.0,np.nan,4.6,4.2,3.5,np.nan]
}

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(data)
df
# Out:
#     EmpID    Name     Dept   Salary  Experience       City   Age  Performance
# 0     101   Arjun  DataSci  82000.0         3.0  Bangalore  26.0          4.3
# 1     102   Meera       ML  95000.0         5.0     Mumbai  29.0          4.8
# 2     103    Ravi  DataEng  76000.0         NaN       Pune  24.0          3.9
# 3     104    Sana  DataSci  88000.0         4.0      Delhi  28.0          NaN
# 4     105   Kiran   DevOps  70000.0         1.0  Hyderabad   NaN          3.7
# 5     106   Divya       ML      NaN         3.0  Bangalore  27.0          4.1
# 6     107   Mohan  DataEng  81000.0         NaN    Chennai  30.0          4.0
# 7     108   Priya   DevOps  69000.0         2.0     Mumbai  23.0          NaN
# 8     109    Amit  DataSci  92000.0         6.0       Pune  31.0          4.6
# 9     110    Neha       ML  84000.0         3.0      Delhi   NaN          4.2
# 10    111  Farhan   DevOps  71000.0         1.0  Bangalore  22.0          3.5
# 11    112    Isha  DataEng  78500.0         2.0  Hyderabad  25.0          NaN

# %%
print(df.describe())


print(df.info())
# Out:
#             EmpID        Salary  Experience       Age  Performance
# count   12.000000     11.000000   10.000000  10.00000     9.000000
# mean   106.500000  80590.909091    3.000000  26.50000     4.122222
# std      3.605551   8777.295090    1.632993   3.02765     0.411636
# min    101.000000  69000.000000    1.000000  22.00000     3.500000
# 25%    103.750000  73500.000000    2.000000  24.25000     3.900000
# 50%    106.500000  81000.000000    3.000000  26.50000     4.100000
# 75%    109.250000  86000.000000    3.750000  28.75000     4.300000
# max    112.000000  95000.000000    6.000000  31.00000     4.800000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmpID        12 non-null     int64
#  1   Name         12 non-null     object
#  2   Dept         12 non-null     object
#  3   Salary       11 non-null     float64
#  4   Experience   10 non-null     float64
#  5   City         12 non-null     object
#  6   Age          10 non-null     float64
#  7   Performance  9 non-null      float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 900.0+ bytes
# None

# %%
df.describe()
# Out:
#             EmpID        Salary  Experience       Age  Performance
# count   12.000000     11.000000   10.000000  10.00000     9.000000
# mean   106.500000  80590.909091    3.000000  26.50000     4.122222
# std      3.605551   8777.295090    1.632993   3.02765     0.411636
# min    101.000000  69000.000000    1.000000  22.00000     3.500000
# 25%    103.750000  73500.000000    2.000000  24.25000     3.900000
# 50%    106.500000  81000.000000    3.000000  26.50000     4.100000
# 75%    109.250000  86000.000000    3.750000  28.75000     4.300000
# max    112.000000  95000.000000    6.000000  31.00000     4.800000

# %%
hk=(df[['Name','Age','City','Salary']]) # columns selection
print(hk)
# Out:
#       Name   Age       City   Salary
# 0    Arjun  26.0  Bangalore  82000.0
# 1    Meera  29.0     Mumbai  95000.0
# 2     Ravi  24.0       Pune  76000.0
# 3     Sana  28.0      Delhi  88000.0
# 4    Kiran   NaN  Hyderabad  70000.0
# 5    Divya  27.0  Bangalore      NaN
# 6    Mohan  30.0    Chennai  81000.0
# 7    Priya  23.0     Mumbai  69000.0
# 8     Amit  31.0       Pune  92000.0
# 9     Neha   NaN      Delhi  84000.0
# 10  Farhan  22.0  Bangalore  71000.0
# 11    Isha  25.0  Hyderabad  78500.0

# %%
#filling missing value
hk.ffill(inplace=False)
# Out:
#       Name   Age       City   Salary
# 0    Arjun  26.0  Bangalore  82000.0
# 1    Meera  29.0     Mumbai  95000.0
# 2     Ravi  24.0       Pune  76000.0
# 3     Sana  28.0      Delhi  88000.0
# 4    Kiran  28.0  Hyderabad  70000.0
# 5    Divya  27.0  Bangalore  70000.0
# 6    Mohan  30.0    Chennai  81000.0
# 7    Priya  23.0     Mumbai  69000.0
# 8     Amit  31.0       Pune  92000.0
# 9     Neha  31.0      Delhi  84000.0
# 10  Farhan  22.0  Bangalore  71000.0
# 11    Isha  25.0  Hyderabad  78500.0

# %%
#filling missing value using interpolate
df.infer_objects(copy=False)
df.interpolate()
# Out:
# /tmp/ipython-input-773506705.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#     EmpID    Name     Dept   Salary  Experience       City   Age  Performance
# 0     101   Arjun  DataSci  82000.0         3.0  Bangalore  26.0          4.3
# 1     102   Meera       ML  95000.0         5.0     Mumbai  29.0          4.8
# 2     103    Ravi  DataEng  76000.0         4.5       Pune  24.0          3.9
# 3     104    Sana  DataSci  88000.0         4.0      Delhi  28.0          3.8
# 4     105   Kiran   DevOps  70000.0         1.0  Hyderabad  27.5          3.7
# 5     106   Divya       ML  75500.0         3.0  Bangalore  27.0          4.1
# 6     107   Mohan  DataEng  81000.0         2.5    Chennai  30.0          4.0
# 7     108   Priya   DevOps  69000.0         2.0     Mumbai  23.0          4.3
# 8     109    Amit  DataSci  92000.0         6.0       Pune  31.0          4.6
# 9     110    Neha       ML  84000.0         3.0      Delhi  26.5          4.2
# 10    111  Farhan   DevOps  71000.0         1.0  Bangalore  22.0          3.5
# 11    112    Isha  DataEng  78500.0         2.0  Hyderabad  25.0          3.5

# %%
# droping null value using dropna
df.dropna(how='any')
# Out:
#     EmpID    Name     Dept   Salary  Experience       City   Age  Performance
# 0     101   Arjun  DataSci  82000.0         3.0  Bangalore  26.0          4.3
# 1     102   Meera       ML  95000.0         5.0     Mumbai  29.0          4.8
# 8     109    Amit  DataSci  92000.0         6.0       Pune  31.0          4.6
# 10    111  Farhan   DevOps  71000.0         1.0  Bangalore  22.0          3.5

# %%
df.dropna(axis=1)
# Out:
#     EmpID    Name     Dept       City
# 0     101   Arjun  DataSci  Bangalore
# 1     102   Meera       ML     Mumbai
# 2     103    Ravi  DataEng       Pune
# 3     104    Sana  DataSci      Delhi
# 4     105   Kiran   DevOps  Hyderabad
# 5     106   Divya       ML  Bangalore
# 6     107   Mohan  DataEng    Chennai
# 7     108   Priya   DevOps     Mumbai
# 8     109    Amit  DataSci       Pune
# 9     110    Neha       ML      Delhi
# 10    111  Farhan   DevOps  Bangalore
# 11    112    Isha  DataEng  Hyderabad

# %%
df
# Out:
#     EmpID    Name     Dept   Salary  Experience       City   Age  Performance
# 0     101   Arjun  DataSci  82000.0         3.0  Bangalore  26.0          4.3
# 1     102   Meera       ML  95000.0         5.0     Mumbai  29.0          4.8
# 2     103    Ravi  DataEng  76000.0         NaN       Pune  24.0          3.9
# 3     104    Sana  DataSci  88000.0         4.0      Delhi  28.0          NaN
# 4     105   Kiran   DevOps  70000.0         1.0  Hyderabad   NaN          3.7
# 5     106   Divya       ML      NaN         3.0  Bangalore  27.0          4.1
# 6     107   Mohan  DataEng  81000.0         NaN    Chennai  30.0          4.0
# 7     108   Priya   DevOps  69000.0         2.0     Mumbai  23.0          NaN
# 8     109    Amit  DataSci  92000.0         6.0       Pune  31.0          4.6
# 9     110    Neha       ML  84000.0         3.0      Delhi   NaN          4.2
# 10    111  Farhan   DevOps  71000.0         1.0  Bangalore  22.0          3.5
# 11    112    Isha  DataEng  78500.0         2.0  Hyderabad  25.0          NaN

# %%
df
# Out:
#    EmpID   Name     Dept   Salary       City   Age
# 0    101  Arjun  DataSci  82000.0  Bangalore  26.0
# 1    102  Meera       ML  95000.0     Mumbai  29.0
# 2    103   Ravi  DataEng  76000.0       Pune  24.0
# 3    104   Sana  DataSci  88000.0      Delhi  28.0
# 4    105  Kiran   DevOps  70000.0  Hyderabad   NaN
# 5    106  Divya       ML      NaN  Bangalore  27.0
# 6    107  Mohan  DataEng  81000.0    Chennai  30.0
# 7    108  Priya   DevOps  69000.0     Mumbai  23.0
# 8    109   Amit  DataSci  92000.0       Pune  31.0

# %%
# deleting rows
df.drop(df.index[9:12],inplace=True)
# Out:
#    EmpID   Name     Dept   Salary       City   Age
# 0    101  Arjun  DataSci  82000.0  Bangalore  26.0
# 1    102  Meera       ML  95000.0     Mumbai  29.0
# 2    103   Ravi  DataEng  76000.0       Pune  24.0
# 3    104   Sana  DataSci  88000.0      Delhi  28.0
# 4    105  Kiran   DevOps  70000.0  Hyderabad   NaN
# 5    106  Divya       ML      NaN  Bangalore  27.0
# 6    107  Mohan  DataEng  81000.0    Chennai  30.0
# 7    108  Priya   DevOps  69000.0     Mumbai  23.0
# 8    109   Amit  DataSci  92000.0       Pune  31.0

# %%
# adding new columns
experience = [3,5,2,4,1,3,5,2,3]
df["Experience"]=experience
df
# Out:
#    EmpID   Name     Dept   Salary       City   Age  Experience
# 0    101  Arjun  DataSci  82000.0  Bangalore  26.0           3
# 1    102  Meera       ML  95000.0     Mumbai  29.0           5
# 2    103   Ravi  DataEng  76000.0       Pune  24.0           2
# 3    104   Sana  DataSci  88000.0      Delhi  28.0           4
# 4    105  Kiran   DevOps  70000.0  Hyderabad   NaN           1
# 5    106  Divya       ML      NaN  Bangalore  27.0           3
# 6    107  Mohan  DataEng  81000.0    Chennai  30.0           5
# 7    108  Priya   DevOps  69000.0     Mumbai  23.0           2
# 8    109   Amit  DataSci  92000.0       Pune  31.0           3

# %%
df.loc[1:4]
# Out:
#    EmpID   Name     Dept   Salary       City   Age  Experience
# 1    102  Meera       ML  95000.0     Mumbai  29.0           5
# 2    103   Ravi  DataEng  76000.0       Pune  24.0           2
# 3    104   Sana  DataSci  88000.0      Delhi  28.0           4
# 4    105  Kiran   DevOps  70000.0  Hyderabad   NaN           1

# %%
df.iloc[1:5, :]
# Out:
#    EmpID   Name     Dept   Salary       City   Age  Experience
# 1    102  Meera       ML  95000.0     Mumbai  29.0           5
# 2    103   Ravi  DataEng  76000.0       Pune  24.0           2
# 3    104   Sana  DataSci  88000.0      Delhi  28.0           4
# 4    105  Kiran   DevOps  70000.0  Hyderabad   NaN           1

# %%
new_row = {
    "EmpID": 113,
    "Name": "Shreya",
    "Dept": "DataSci",
    "Salary": 86000,
    "Experience": 3,
    "City": "Chennai",
    "Performance": 4.4
}

ndf=pd.DataFrame([new_row])
print(type(ndf))
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'bool'>

# %%
df = pd.concat([ndf, df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3255512807.py in <cell line: 0>()
# ----> 1 df = pd.concat([ndf, df], ignore_index=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380         copy = False
#     381
# --> 382     op = _Concatenator(
#     383         objs,
#     384         axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     446
#     447         # figure out what our result ndim is going to be
# --> 448         ndims = self._get_ndims(objs)
#     449         sample, objs = self._get_sample_object(objs, ndims, keys, names, levels)
#     450
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in _get_ndims(self, objs)
#     487                     "only Series and DataFrame objs are valid"
#     488                 )
# --> 489                 raise TypeError(msg)
#     490
#     491             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'bool'>'; only Series and DataFrame objs are valid

# %%
data = {
    "EmpID": [101,102,103,104,105,106,107,108,109,110,111,112],
    "Name": ["Arjun","Meera","Ravi","Sana","Kiran","Divya","Mohan","Priya","Amit","Neha","Farhan","Isha"],
    "Dept": ["DataSci","ML","DataEng","DataSci","DevOps","ML","DataEng","DevOps","DataSci","ML","DevOps","DataEng"],
    "Salary": [82000,95000,76000,88000,70000, np.nan, 81000,69000,92000,84000,71000,78500],
    "Experience": [3,5,2,4,1,3,5,2,6,3,1,2],
    "City": ["Bangalore","Mumbai","Pune","Delhi","Hyderabad","Bangalore","Chennai","Mumbai","Pune","Delhi","Bangalore","Hyderabad"],
    "Age": [26,29,24,28,np.nan,27,30,23,31,np.nan,22,25],
    "Performance": [4.3,4.8,3.9,np.nan,3.7,4.1,4.0,np.nan,4.6,4.2,3.5,np.nan]
}

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(data)
df
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
new_row = {
    "EmpID": 113,
    "Name": "Shreya",
    "Dept": "DataSci",
    "Salary": 86000,
    "Experience": 3,
    "City": "Chennai",
    "Performance": 4.4
}

ndf=pd.DataFrame([new_row])
ndf
# Out:
#    EmpID    Name     Dept  Salary  Experience     City  Performance
# 0    113  Shreya  DataSci   86000           3  Chennai          4.4

# %%
df=pd.concat([ndf,df], ignore_index=True)
df
# Out:
#     EmpID    Name     Dept   Salary  Experience       City  Performance   Age
# 0     113  Shreya  DataSci  86000.0           3    Chennai          4.4   NaN
# 1     113  Shreya  DataSci  86000.0           3    Chennai          4.4   NaN
# 2     101   Arjun  DataSci  82000.0           3  Bangalore          4.3  26.0
# 3     102   Meera       ML  95000.0           5     Mumbai          4.8  29.0
# 4     103    Ravi  DataEng  76000.0           2       Pune          3.9  24.0
# 5     104    Sana  DataSci  88000.0           4      Delhi          NaN  28.0
# 6     105   Kiran   DevOps  70000.0           1  Hyderabad          3.7   NaN
# 7     106   Divya       ML      NaN           3  Bangalore          4.1  27.0
# 8     107   Mohan  DataEng  81000.0           5    Chennai          4.0  30.0
# 9     108   Priya   DevOps  69000.0           2     Mumbai          NaN  23.0
# 10    109    Amit  DataSci  92000.0           6       Pune          4.6  31.0
# 11    110    Neha       ML  84000.0           3      Delhi          4.2   NaN
# 12    111  Farhan   DevOps  71000.0           1  Bangalore          3.5  22.0
# 13    112    Isha  DataEng  78500.0           2  Hyderabad          NaN  25.0

# %%
print(df.shape)
df.tail()
# Out:
# (14, 8)
#     EmpID    Name     Dept   Salary  Experience       City  Performance   Age
# 9     108   Priya   DevOps  69000.0           2     Mumbai          NaN  23.0
# 10    109    Amit  DataSci  92000.0           6       Pune          4.6  31.0
# 11    110    Neha       ML  84000.0           3      Delhi          4.2   NaN
# 12    111  Farhan   DevOps  71000.0           1  Bangalore          3.5  22.0
# 13    112    Isha  DataEng  78500.0           2  Hyderabad          NaN  25.0

# %%
df.head()
# Out:
#    EmpID    Name     Dept   Salary  Experience       City  Performance   Age
# 0    113  Shreya  DataSci  86000.0           3    Chennai          4.4   NaN
# 1    113  Shreya  DataSci  86000.0           3    Chennai          4.4   NaN
# 2    101   Arjun  DataSci  82000.0           3  Bangalore          4.3  26.0
# 3    102   Meera       ML  95000.0           5     Mumbai          4.8  29.0
# 4    103    Ravi  DataEng  76000.0           2       Pune          3.9  24.0

# %%
df.truncate(before=3,after=7)
# Out:
#    EmpID   Name     Dept   Salary  Experience       City  Performance   Age
# 3    102  Meera       ML  95000.0           5     Mumbai          4.8  29.0
# 4    103   Ravi  DataEng  76000.0           2       Pune          3.9  24.0
# 5    104   Sana  DataSci  88000.0           4      Delhi          NaN  28.0
# 6    105  Kiran   DevOps  70000.0           1  Hyderabad          3.7   NaN
# 7    106  Divya       ML      NaN           3  Bangalore          4.1  27.0

# %%
# Out:
#          farmer_name           state       crop  season planting_date  \
# 0      Lakshmi Patel         Gujarat    Coconut    Rabi    2022-05-06
# 1          Radha Rao       Karnataka    Mustard    Zaid    2024-06-02
# 2         Anil Gupta         Haryana     Potato  Kharif    2021-11-09
# 3       Savita Joshi          Odisha  Sugarcane    Zaid    2022-09-07
# 4        Prakash Rao   Uttar Pradesh  Groundnut  Kharif    2023-07-08
# ...              ...             ...        ...     ...           ...
# 1495  Prakash Pillai   Uttar Pradesh      Onion    Zaid    2021-07-03
# 1496    Kamala Verma           Bihar    Coconut    Zaid    2024-02-14
# 1497    Dinesh Singh         Haryana    Coconut    Zaid    2021-06-11
# 1498      Mahesh Rao  Andhra Pradesh    Soybean    Zaid    2022-06-27
# 1499      Amit Reddy       Karnataka     Potato    Rabi    2024-06-14
#
#       area_hectares  duration_days
# 0             24.85            130
# 1             15.86            142
# 2              9.50            116
# 3             25.45            179
# 4             16.48            152
# ...             ...            ...
# 1495          17.61            114
# 1496          31.26            116
# 1497           2.42            167
# 1498           9.75            146
# 1499          41.65            156
#
# [1500 rows x 7 columns]

# %%
df.sort_values(["state","farmer_name"], axis=0, ascending=True, na_position='last')
# Out:
#        farmer_name           state       crop  season planting_date  \
# 1043     Ajay Nair  Andhra Pradesh      Onion  Kharif    2024-10-20
# 1224     Ajay Nair  Andhra Pradesh      Wheat    Zaid    2023-12-31
# 110    Ajay Pillai  Andhra Pradesh      Wheat    Rabi    2024-04-27
# 1197   Ajay Pillai  Andhra Pradesh    Mustard  Kharif    2022-01-27
# 795      Amit Naik  Andhra Pradesh    Coconut  Kharif    2022-06-06
# ...            ...             ...        ...     ...           ...
# 868    Sita Pillai     West Bengal    Millets  Kharif    2024-02-18
# 970     Suresh Rao     West Bengal     Potato    Zaid    2021-10-09
# 96    Suresh Reddy     West Bengal  Sugarcane    Zaid    2024-11-12
# 686   Suresh Verma     West Bengal    Millets    Zaid    2021-05-28
# 290   Vijay Sharma     West Bengal      Maize  Kharif    2024-06-13
#
#       area_hectares  duration_days
# 1043          28.18            104
# 1224           4.94            140
# 110           12.61            149
# 1197          28.78            148
# 795           36.37            138
# ...             ...            ...
# 868           17.25            103
# 970           48.46             71
# 96            35.91            177
# 686            7.71            144
# 290           45.83             78
#
# [1500 rows x 7 columns]

# %%
grouped_by_crop = ndf.groupby('crop').mean(numeric_only=True)
grouped_by_crop
# Out:
#            area_hectares  duration_days
# crop
# Coconut        25.960833     105.500000
# Cotton         23.850000     116.684211
# Groundnut      23.205556     125.333333
# Maize          26.622857     125.357143
# Millets        27.654737     121.736842
# Mustard        28.646364     119.136364
# Onion          22.753077     120.923077
# Potato         20.040909     115.545455
# Soybean        20.396111     126.888889
# Sugarcane      25.840909     121.545455
# Tomato         25.573333     117.800000
# Wheat          24.862353     103.294118

# %%
df=pd.read_csv('/content/agri_data_100rows.csv')
df
# Out:
#    Farmer_Name           State       Crop  Season  Area_acres  Yield_tonnes  \
# 0        Karan          Punjab    Soybean  Kharif        5.03          4.50
# 1        Meena     Maharashtra  Sugarcane  Kharif        7.37          9.13
# 2        Pooja         Haryana     Pulses    Rabi        5.27         13.14
# 3       Suresh         Haryana      Wheat  Annual       10.28          8.87
# 4        Karan  Madhya Pradesh      Wheat  Kharif        4.72          4.34
# ..         ...             ...        ...     ...         ...           ...
# 95       Divya  Madhya Pradesh    Soybean  Kharif        6.23         14.42
# 96        Anil         Gujarat     Pulses  Kharif        7.69          1.81
# 97       Karan      Tamil Nadu    Soybean    Rabi        7.76          6.52
# 98        Anil          Punjab    Soybean  Kharif        9.32          2.49
# 99       Pooja       Rajasthan    Soybean  Kharif        3.28          5.70
#
#    Soil_Type  Rainfall_mm
# 0   Alluvial          834
# 1      Sandy          846
# 2      Sandy          707
# 3   Alluvial          648
# 4   Alluvial          565
# ..       ...          ...
# 95  Alluvial          764
# 96  Alluvial         1065
# 97  Alluvial          925
# 98  Alluvial         1098
# 99       Red          711
#
# [100 rows x 8 columns]

# %%
ndf=df.groupby(['Crop'])
ndf.sum(numeric_only=True)
# Out:
#            Area_acres  Yield_tonnes  Avg_Yield
# Crop
# Cotton         129.40        147.12   160.5481
# Maize           34.73         37.14    50.6994
# Pulses          66.55         86.76    84.4990
# Rice            65.25         88.92    76.0491
# Soybean        104.06        114.32   126.7485
# Sugarcane      136.57        200.29   168.9980
# Wheat          151.66        170.44   177.4479

# %%
df.drop(["Rainfall_mm"],axis=1,inplace=True, errors="ignore")
df
# Out:
#    Farmer_Name           State       Crop  Season  Area_acres  Yield_tonnes  \
# 0        Karan          Punjab    Soybean  Kharif        5.03          4.50
# 1        Meena     Maharashtra  Sugarcane  Kharif        7.37          9.13
# 2        Pooja         Haryana     Pulses    Rabi        5.27         13.14
# 3       Suresh         Haryana      Wheat  Annual       10.28          8.87
# 4        Karan  Madhya Pradesh      Wheat  Kharif        4.72          4.34
# ..         ...             ...        ...     ...         ...           ...
# 95       Divya  Madhya Pradesh    Soybean  Kharif        6.23         14.42
# 96        Anil         Gujarat     Pulses  Kharif        7.69          1.81
# 97       Karan      Tamil Nadu    Soybean    Rabi        7.76          6.52
# 98        Anil          Punjab    Soybean  Kharif        9.32          2.49
# 99       Pooja       Rajasthan    Soybean  Kharif        3.28          5.70
#
#    Soil_Type
# 0   Alluvial
# 1      Sandy
# 2      Sandy
# 3   Alluvial
# 4   Alluvial
# ..       ...
# 95  Alluvial
# 96  Alluvial
# 97  Alluvial
# 98  Alluvial
# 99       Red
#
# [100 rows x 7 columns]

# %%
df["Avg_Yield"] = df["Yield_tonnes"].mean()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Yield_tonnes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2657815580.py in <cell line: 0>()
# ----> 1 df["Avg_Yield"] = df["Yield_tonnes"].mean()
#       2 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Yield_tonnes'

# %%
df[df['State'] != 'Bihar']
# Out:
#    Farmer_Name           State       Crop  Season  Area_acres  Yield_tonnes  \
# 0        Karan          Punjab    Soybean  Kharif        5.03          4.50
# 1        Meena     Maharashtra  Sugarcane  Kharif        7.37          9.13
# 2        Pooja         Haryana     Pulses    Rabi        5.27         13.14
# 3       Suresh         Haryana      Wheat  Annual       10.28          8.87
# 4        Karan  Madhya Pradesh      Wheat  Kharif        4.72          4.34
# ..         ...             ...        ...     ...         ...           ...
# 95       Divya  Madhya Pradesh    Soybean  Kharif        6.23         14.42
# 96        Anil         Gujarat     Pulses  Kharif        7.69          1.81
# 97       Karan      Tamil Nadu    Soybean    Rabi        7.76          6.52
# 98        Anil          Punjab    Soybean  Kharif        9.32          2.49
# 99       Pooja       Rajasthan    Soybean  Kharif        3.28          5.70
#
#    Soil_Type  Avg_Yield
# 0   Alluvial     8.4499
# 1      Sandy     8.4499
# 2      Sandy     8.4499
# 3   Alluvial     8.4499
# 4   Alluvial     8.4499
# ..       ...        ...
# 95  Alluvial     8.4499
# 96  Alluvial     8.4499
# 97  Alluvial     8.4499
# 98  Alluvial     8.4499
# 99       Red     8.4499
#
# [92 rows x 8 columns]

# %%
df.groupby('State')
print(df.groupby('State').groups)
# Out:
# {'Bihar': [19, 36, 42, 46, 47, 49, 54, 62], 'Gujarat': [5, 12, 15, 27, 37, 55, 72, 81, 86, 96], 'Haryana': [2, 3, 17, 18, 23, 28, 29, 31, 41, 43, 51, 68, 80, 89, 91], 'Karnataka': [6, 9, 11, 13, 22, 32, 50, 57, 70, 84], 'Madhya Pradesh': [4, 7, 53, 59, 61, 74, 92, 95], 'Maharashtra': [1, 10, 14, 24, 44, 45, 56, 64, 65, 71, 73, 75, 76, 82, 83, 93], 'Odisha': [16, 20, 21, 35, 40, 58, 66, 87], 'Punjab': [0, 34, 69, 77, 78, 85, 98], 'Rajasthan': [8, 33, 38, 52, 60, 79, 88, 94, 99], 'Tamil Nadu': [25, 26, 30, 39, 48, 63, 67, 90, 97]}

# %%
df=df[~df["State"].isin(['Bihar','Rajasthan','Odisha'])]
df
# Out:
#    Farmer_Name           State       Crop  Season  Area_acres  Yield_tonnes  \
# 0        Karan          Punjab    Soybean  Kharif        5.03          4.50
# 1        Meena     Maharashtra  Sugarcane  Kharif        7.37          9.13
# 2        Pooja         Haryana     Pulses    Rabi        5.27         13.14
# 3       Suresh         Haryana      Wheat  Annual       10.28          8.87
# 4        Karan  Madhya Pradesh      Wheat  Kharif        4.72          4.34
# ..         ...             ...        ...     ...         ...           ...
# 93       Divya     Maharashtra  Sugarcane  Kharif       11.68         11.32
# 95       Divya  Madhya Pradesh    Soybean  Kharif        6.23         14.42
# 96        Anil         Gujarat     Pulses  Kharif        7.69          1.81
# 97       Karan      Tamil Nadu    Soybean    Rabi        7.76          6.52
# 98        Anil          Punjab    Soybean  Kharif        9.32          2.49
#
#    Soil_Type  Avg_Yield
# 0   Alluvial     8.4499
# 1      Sandy     8.4499
# 2      Sandy     8.4499
# 3   Alluvial     8.4499
# 4   Alluvial     8.4499
# ..       ...        ...
# 93       Red     8.4499
# 95  Alluvial     8.4499
# 96  Alluvial     8.4499
# 97  Alluvial     8.4499
# 98  Alluvial     8.4499
#
# [75 rows x 8 columns]

# %%
df.groupby('State').mean(numeric_only=True)
# Out:
#                 Area_acres  Yield_tonnes  Avg_Yield
# State
# Gujarat           5.999000      7.690000     8.4499
# Haryana           6.378000      9.196000     8.4499
# Karnataka         7.812000      8.169000     8.4499
# Madhya Pradesh    7.887500      7.730000     8.4499
# Maharashtra       7.508750      8.846875     8.4499
# Punjab            5.618571      9.627143     8.4499
# Tamil Nadu        9.058889      9.055556     8.4499

# %%
kdf=df.groupby("State")['Area_acres'].agg(['count', 'mean', 'min', 'max'])
kdf.sort_values('count',ascending=False)
# Out:
#                 count      mean   min    max
# State
# Maharashtra        16  7.508750  2.15  11.80
# Haryana            15  6.378000  2.39  10.28
# Gujarat            10  5.999000  2.41  11.65
# Karnataka          10  7.812000  3.38  11.70
# Tamil Nadu          9  9.058889  3.20  11.44
# Madhya Pradesh      8  7.887500  4.72  11.49
# Punjab              7  5.618571  3.29   9.32

# %%
df.agg({'Area_acres': ['sum','mean','std']})
# Out:
#       Area_acres
# sum   537.880000
# mean    7.171733
# std     2.816771

# %%
df=pd.DataFrame({"P":range(5),"Q":range(2,7)})
df
# Out:
#    P  Q
# 0  0  2
# 1  1  3
# 2  2  4
# 3  3  5
# 4  4  6

# %%
df.transform(lambda x:x+2)
# Out:
#    P  Q
# 0  2  4
# 1  3  5
# 2  4  6
# 3  5  7
# 4  6  8

# %%
df.shape
# Out:
# (5, 2)

# %%
print(type(ndf))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/product_sales_500.csv')
df
# Out:
#     InvoiceID                           Date     Product  UnitPrice  Quantity  \
# 0     INV1000  2024-01-01 00:00:00.000000000       Mouse        390         6
# 1     INV1001  2024-01-01 08:42:19.478957915     Charger       2500         1
# 2     INV1002  2024-01-01 17:24:38.957915831     Monitor       1180         8
# 3     INV1003  2024-01-02 02:06:58.436873747       Mouse       3175         6
# 4     INV1004  2024-01-02 10:49:17.915831663  Headphones       1384         3
# ..        ...                            ...         ...        ...       ...
# 495   INV1495  2024-06-28 13:10:42.084168336       Mouse        205         5
# 496   INV1496  2024-06-28 21:53:01.563126252  Headphones        667         6
# 497   INV1497  2024-06-29 06:35:21.042084168     Charger       4370         7
# 498   INV1498  2024-06-29 15:17:40.521042084      Laptop        203         1
# 499   INV1499  2024-06-30 00:00:00.000000000     Charger        845         9
#
#     PaymentMethod Branch  Total
# 0             UPI      A   2340
# 1     Net Banking      B   2500
# 2     Credit Card      B   9440
# 3            Cash      C  19050
# 4            Cash      B   4152
# ..            ...    ...    ...
# 495           UPI      C   1025
# 496   Net Banking      B   4002
# 497          Cash      B  30590
# 498   Net Banking      B    203
# 499   Credit Card      B   7605
#
# [500 rows x 8 columns]

# %%
df.drop(['Date'],axis=1,inplace=True)
df
# Out:
#     InvoiceID     Product  UnitPrice  Quantity PaymentMethod Branch  Total
# 0     INV1000       Mouse        390         6           UPI      A   2340
# 1     INV1001     Charger       2500         1   Net Banking      B   2500
# 2     INV1002     Monitor       1180         8   Credit Card      B   9440
# 3     INV1003       Mouse       3175         6          Cash      C  19050
# 4     INV1004  Headphones       1384         3          Cash      B   4152
# ..        ...         ...        ...       ...           ...    ...    ...
# 495   INV1495       Mouse        205         5           UPI      C   1025
# 496   INV1496  Headphones        667         6   Net Banking      B   4002
# 497   INV1497     Charger       4370         7          Cash      B  30590
# 498   INV1498      Laptop        203         1   Net Banking      B    203
# 499   INV1499     Charger        845         9   Credit Card      B   7605
#
# [500 rows x 7 columns]

# %%
import pandas as pd
df = pd.read_csv('/content/product_sales_500.csv')
df.drop(['Date'], axis=1, inplace=True)
df['Product'].value_counts()
# Out:
# Product
# Charger       76
# Smartwatch    72
# Laptop        71
# Headphones    64
# Keyboard      62
# Mouse         58
# Monitor       51
# Mobile        46
# Name: count, dtype: int64

# %%
df
# Out:
#     InvoiceID     Product  UnitPrice  Quantity PaymentMethod Branch  Total
# 0     INV1000       Mouse        390         6           UPI      A   2340
# 1     INV1001     Charger       2500         1   Net Banking      B   2500
# 2     INV1002     Monitor       1180         8   Credit Card      B   9440
# 3     INV1003       Mouse       3175         6          Cash      C  19050
# 4     INV1004  Headphones       1384         3          Cash      B   4152
# ..        ...         ...        ...       ...           ...    ...    ...
# 495   INV1495       Mouse        205         5           UPI      C   1025
# 496   INV1496  Headphones        667         6   Net Banking      B   4002
# 497   INV1497     Charger       4370         7          Cash      B  30590
# 498   INV1498      Laptop        203         1   Net Banking      B    203
# 499   INV1499     Charger        845         9   Credit Card      B   7605
#
# [500 rows x 7 columns]

# %%
import pandas as pd
import numpy as np

# Create a 7-dimensional India farming dataset for practice
np.random.seed(42)

# Dimension 1: Farmer Names (Indian names)
first_names = ['Ramesh', 'Suresh', 'Rajesh', 'Mahesh', 'Ganesh', 'Dinesh', 'Prakash',
               'Amit', 'Vijay', 'Ajay', 'Ravi', 'Krishna', 'Mohan', 'Gopal', 'Anil',
               'Lakshmi', 'Savita', 'Kamala', 'Radha', 'Sita', 'Gita', 'Priya', 'Meera']
last_names = ['Kumar', 'Singh', 'Patel', 'Sharma', 'Reddy', 'Rao', 'Nair', 'Desai',
              'Yadav', 'Joshi', 'Gupta', 'Verma', 'Chauhan', 'Pillai', 'Naik']
farmer_names = [f'{np.random.choice(first_names)} {np.random.choice(last_names)}'
                for _ in range(300)]

# Dimension 2: States/Regions in India
states = ['Punjab', 'Haryana', 'Uttar Pradesh', 'Madhya Pradesh', 'Maharashtra',
          'Karnataka', 'Tamil Nadu', 'Andhra Pradesh', 'West Bengal', 'Gujarat',
          'Rajasthan', 'Bihar', 'Odisha', 'Kerala', 'Telangana']

# Dimension 3: Crop Types
crops = [ 'Wheat', 'Cotton', 'Sugarcane', 'Maize', 'Groundnut',
         'Soybean', 'Millets',  'Mustard','Coconut', 'Potato',
          'Onion', 'Tomato']

# Dimension 4: Season
seasons = ['Kharif', 'Rabi', 'Zaid']  # Indian agricultural seasons

# Dimension 5: Year and Month (Planting Date)
years = [2021, 2022, 2023, 2024]
dates = pd.date_range('2021-01-01', '2024-12-31', freq='D')

# Generate 1500 sample farming records
data = {
    'farmer_name': np.random.choice(farmer_names, 1500),
    'state': np.random.choice(states, 1500),
    'crop': np.random.choice(crops, 1500),
    'season': np.random.choice(seasons, 1500),
    'planting_date': np.random.choice(dates, 1500),
    'area_hectares': np.random.uniform(0.5, 50, 1500).round(2),
    'duration_days': np.random.randint(60, 180, 1500)
}
df=pd.DataFrame(data)
df
# Out:
#          farmer_name           state       crop  season planting_date  \
# 0      Lakshmi Patel         Gujarat    Coconut    Rabi    2022-05-06
# 1          Radha Rao       Karnataka    Mustard    Zaid    2024-06-02
# 2         Anil Gupta         Haryana     Potato  Kharif    2021-11-09
# 3       Savita Joshi          Odisha  Sugarcane    Zaid    2022-09-07
# 4        Prakash Rao   Uttar Pradesh  Groundnut  Kharif    2023-07-08
# ...              ...             ...        ...     ...           ...
# 1495  Prakash Pillai   Uttar Pradesh      Onion    Zaid    2021-07-03
# 1496    Kamala Verma           Bihar    Coconut    Zaid    2024-02-14
# 1497    Dinesh Singh         Haryana    Coconut    Zaid    2021-06-11
# 1498      Mahesh Rao  Andhra Pradesh    Soybean    Zaid    2022-06-27
# 1499      Amit Reddy       Karnataka     Potato    Rabi    2024-06-14
#
#       area_hectares  duration_days
# 0             24.85            130
# 1             15.86            142
# 2              9.50            116
# 3             25.45            179
# 4             16.48            152
# ...             ...            ...
# 1495          17.61            114
# 1496          31.26            116
# 1497           2.42            167
# 1498           9.75            146
# 1499          41.65            156
#
# [1500 rows x 7 columns]

# %%
df.drop(["farmer_name"],axis=1,inplace=True)
df
# Out:
#                state       crop  season planting_date  area_hectares  \
# 0            Gujarat    Coconut    Rabi    2022-05-06          24.85
# 1          Karnataka    Mustard    Zaid    2024-06-02          15.86
# 2            Haryana     Potato  Kharif    2021-11-09           9.50
# 3             Odisha  Sugarcane    Zaid    2022-09-07          25.45
# 4      Uttar Pradesh  Groundnut  Kharif    2023-07-08          16.48
# ...              ...        ...     ...           ...            ...
# 1495   Uttar Pradesh      Onion    Zaid    2021-07-03          17.61
# 1496           Bihar    Coconut    Zaid    2024-02-14          31.26
# 1497         Haryana    Coconut    Zaid    2021-06-11           2.42
# 1498  Andhra Pradesh    Soybean    Zaid    2022-06-27           9.75
# 1499       Karnataka     Potato    Rabi    2024-06-14          41.65
#
#       duration_days
# 0               130
# 1               142
# 2               116
# 3               179
# 4               152
# ...             ...
# 1495            114
# 1496            116
# 1497            167
# 1498            146
# 1499            156
#
# [1500 rows x 6 columns]

# %%
State=df.groupby('state')
State

# %%
len(State)
# Out:
# 15

# %%
State.size().sort_values(ascending=False)
# Out:
# state
# Bihar             113
# Maharashtra       113
# Uttar Pradesh     112
# Madhya Pradesh    108
# Kerala            107
# Andhra Pradesh    104
# West Bengal       101
# Odisha             99
# Punjab             97
# Karnataka          96
# Haryana            95
# Telangana          93
# Tamil Nadu         89
# Gujarat            87
# Rajasthan          86
# dtype: int64

# %%
State.last()
# Out:
#                      crop  season planting_date  area_hectares  duration_days
# state
# Andhra Pradesh    Soybean    Zaid    2022-06-27           9.75            146
# Bihar             Coconut    Zaid    2024-02-14          31.26            116
# Gujarat         Sugarcane    Rabi    2024-02-05           3.50            103
# Haryana           Coconut    Zaid    2021-06-11           2.42            167
# Karnataka          Potato    Rabi    2024-06-14          41.65            156
# Kerala             Cotton    Zaid    2021-08-15          22.08             99
# Madhya Pradesh     Tomato  Kharif    2022-12-31          46.46            158
# Maharashtra         Wheat  Kharif    2022-12-29          38.68             82
# Odisha            Millets    Zaid    2023-04-19          33.52            129
# Punjab            Coconut    Zaid    2021-04-27          45.62            129
# Rajasthan       Groundnut  Kharif    2022-06-01           4.63            164
# Tamil Nadu        Soybean    Rabi    2022-11-24          27.06            145
# Telangana         Millets  Kharif    2021-06-22          12.42            150
# Uttar Pradesh       Onion    Zaid    2021-07-03          17.61            114
# West Bengal        Cotton    Zaid    2024-03-10          34.03            178

# %%
State.get_group("Maharashtra")
# Out:
#             state       crop  season planting_date  area_hectares  \
# 17    Maharashtra     Cotton    Zaid    2022-10-08          41.80
# 49    Maharashtra    Mustard    Zaid    2023-06-12          47.18
# 52    Maharashtra      Onion  Kharif    2022-12-03          35.66
# 80    Maharashtra     Cotton    Zaid    2023-10-31          35.22
# 98    Maharashtra     Cotton    Rabi    2021-09-29          16.13
# ...           ...        ...     ...           ...            ...
# 1452  Maharashtra  Sugarcane    Zaid    2023-03-25          18.31
# 1453  Maharashtra      Onion    Zaid    2023-04-26          27.27
# 1460  Maharashtra    Millets    Zaid    2023-02-09          32.28
# 1471  Maharashtra     Tomato    Rabi    2023-04-15          27.56
# 1475  Maharashtra      Wheat  Kharif    2022-12-29          38.68
#
#       duration_days
# 17               98
# 49               83
# 52              164
# 80              175
# 98              109
# ...             ...
# 1452             64
# 1453             94
# 1460             94
# 1471            106
# 1475             82
#
# [113 rows x 6 columns]

# %%
State.mean(numeric_only=True)
# Out:
#                 area_hectares  duration_days
# state
# Andhra Pradesh      26.002212     123.490385
# Bihar               25.748496     119.929204
# Gujarat             26.123908     119.701149
# Haryana             26.322421     119.673684
# Karnataka           26.584583     117.156250
# Kerala              25.212710     120.943925
# Madhya Pradesh      27.094444     121.898148
# Maharashtra         24.660531     119.345133
# Odisha              24.931010     118.313131
# Punjab              24.490619     116.752577
# Rajasthan           22.759070     126.616279
# Tamil Nadu          23.431573     120.000000
# Telangana           25.500968     119.752688
# Uttar Pradesh       25.317946     119.758929
# West Bengal         21.033465     114.851485

# %%
import pandas as pd

data1 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 28],
    'Education': ['Bachelor', 'Master', 'PhD', 'Bachelor'],
    'Habitat': ['Urban', 'Suburban', 'Urban', 'Rural']
}

df1 = pd.DataFrame(data1)

(df1)
# Out:
#       Name  Age Education   Habitat
# 0    Alice   25  Bachelor     Urban
# 1      Bob   30    Master  Suburban
# 2  Charlie   35       PhD     Urban
# 3    David   28  Bachelor     Rural

# %%
data2 = {
    'Name': ['Alice', 'George', 'Hannah', 'Bob' ],
    'Age': [26, 31, 27, 30],
    'Education': ['Master', 'Bachelor', 'PhD', 'Master'],
    'Habitat': ['Urban', 'Rural', 'Suburban', 'Urban']
}

df2 = pd.DataFrame(data2,index=[0,3,2,1])
(df2)
# Out:
#      Name  Age Education   Habitat
# 0   Alice   26    Master     Urban
# 3  George   31  Bachelor     Rural
# 2  Hannah   27       PhD  Suburban
# 1     Bob   30    Master     Urban

# %%
# stacking two dataframes using concatenate method
import pandas as pd
df=pd.concat([df2,df1],ignore_index=True)
df
# Out:
#       Name  Age Education   Habitat
# 0    Alice   26    Master     Urban
# 1   George   31  Bachelor     Rural
# 2   Hannah   27       PhD  Suburban
# 3      Bob   30    Master     Urban
# 4    Alice   25  Bachelor     Urban
# 5      Bob   30    Master  Suburban
# 6  Charlie   35       PhD     Urban
# 7    David   28  Bachelor     Rural

# %%
# using inner function
df=pd.concat([df1,df2],axis=1,join='inner')
df
# Out:
#       Name  Age Education   Habitat    Name  Age Education   Habitat
# 0    Alice   25  Bachelor     Urban   Alice   26    Master     Urban
# 1      Bob   30    Master  Suburban     Bob   30    Master     Urban
# 2  Charlie   35       PhD     Urban  Hannah   27       PhD  Suburban
# 3    David   28  Bachelor     Rural  George   31  Bachelor     Rural

# %%
df=pd.concat([df2,df1],axis=1,sort=False)
df
# Out:
#      Name  Age Education   Habitat     Name  Age Education   Habitat
# 0   Alice   26    Master     Urban    Alice   25  Bachelor     Urban
# 3  George   31  Bachelor     Rural    David   28  Bachelor     Rural
# 2  Hannah   27       PhD  Suburban  Charlie   35       PhD     Urban
# 1     Bob   30    Master     Urban      Bob   30    Master  Suburban

# %%
#concatenate series and dataframe
s1=pd.Series([64000,25000,38000,41000,25000],name='Salary')
print(s1)
df=pd.concat([df2,s1],axis=1)
df
# Out:
# 0    64000
# 1    25000
# 2    38000
# 3    41000
# 4    25000
# Name: Salary, dtype: int64
#      Name   Age Education   Habitat  Salary
# 0   Alice  26.0    Master     Urban   64000
# 3  George  31.0  Bachelor     Rural   41000
# 2  Hannah  27.0       PhD  Suburban   38000
# 1     Bob  30.0    Master     Urban   25000
# 4     NaN   NaN       NaN       NaN   25000

# %% [markdown]
# **Merging two dataframes**

# %%
df
# Out:
#      Name   Age Education   Habitat  Salary
# 0   Alice  26.0    Master     Urban   64000
# 3  George  31.0  Bachelor     Rural   41000
# 2  Hannah  27.0       PhD  Suburban   38000
# 1     Bob  30.0    Master     Urban   25000
# 4     NaN   NaN       NaN       NaN   25000

# %%
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}

df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
print(df1)

print(df2)
# Out:
#   key    Name  Age
# 0  K0     Jai   27
# 1  K1  Princi   24
# 2  K2  Gaurav   22
# 3  K3    Anuj   32
#   key    Address Qualification
# 0  K0     Nagpur         Btech
# 1  K1     Kanpur           B.A
# 2  K2  Allahabad          Bcom
# 3  K3    Kannuaj        B.hons

# %%
df=pd.merge(df1,df2,on='key')
df
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],}

data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
print(df1)
print(df2)
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32
#   key key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad          Bcom
# 3  K3   K0    Kannuaj        B.hons

# %%
#merging two dataframes using merge function and replace null values using .replace method
import pandas as pd
import numpy as np
df=df1.merge(df2,how='left',on=['key','key1'])
print(df)
df.loc[1, "Address"] = "Pune"  # to replace value at specific position
df.iloc[3,4]="Mumbai"
df["Qualification"]=df["Qualification"].replace(np.nan,'Bsc') # to replce all null value in column at once
df
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K1   K1  Princi   24        NaN           NaN
# 2  K2   K0  Gaurav   22  Allahabad          Bcom
# 3  K3   K1    Anuj   32        NaN           NaN
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K1   K1  Princi   24       Pune           Bsc
# 2  K2   K0  Gaurav   22  Allahabad          Bcom
# 3  K3   K1    Anuj   32     Mumbai           Bsc

# %%
df=pd.merge(df1,df2,how='outer',on=['key','key1'])
df
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K0     NaN   NaN     Kanpur           B.A
# 2  K1   K1  Princi  24.0        NaN           NaN
# 3  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 4  K3   K0     NaN   NaN    Kannuaj        B.hons
# 5  K3   K1    Anuj  32.0        NaN           NaN

# %%
df=pd.merge(df1,df2)
df
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
import pandas as pd

df1 = pd.DataFrame({
    'A': [1],
    'B': [2]
})

df2 = pd.DataFrame({
    'B': [3],
    'C': [4]
})

df = pd.concat([df1, df2], axis=0)
df
# Out:
#      A  B    C
# 0  1.0  2  NaN
# 0  NaN  3  4.0

# %% [markdown]
# **Pandas_Date_Time**

# %%
import pandas as pd
import numpy as np
df=pd.date_range('3-12-2025', periods=10 ,freq='D')
df1=pd.Series(df)
df1
# Out:
# 0   2025-03-12
# 1   2025-03-13
# 2   2025-03-14
# 3   2025-03-15
# 4   2025-03-16
# 5   2025-03-17
# 6   2025-03-18
# 7   2025-03-19
# 8   2025-03-20
# 9   2025-03-21
# dtype: datetime64[ns]

# %%
import pandas as pd
df = pd.read_csv('/content/product_sales_500.csv')
df
# Out:
#     InvoiceID                           Date     Product  UnitPrice  Quantity  \
# 0     INV1000  2024-01-01 00:00:00.000000000       Mouse        390         6
# 1     INV1001  2024-01-01 08:42:19.478957915     Charger       2500         1
# 2     INV1002  2024-01-01 17:24:38.957915831     Monitor       1180         8
# 3     INV1003  2024-01-02 02:06:58.436873747       Mouse       3175         6
# 4     INV1004  2024-01-02 10:49:17.915831663  Headphones       1384         3
# ..        ...                            ...         ...        ...       ...
# 495   INV1495  2024-06-28 13:10:42.084168336       Mouse        205         5
# 496   INV1496  2024-06-28 21:53:01.563126252  Headphones        667         6
# 497   INV1497  2024-06-29 06:35:21.042084168     Charger       4370         7
# 498   INV1498  2024-06-29 15:17:40.521042084      Laptop        203         1
# 499   INV1499  2024-06-30 00:00:00.000000000     Charger        845         9
#
#     PaymentMethod Branch  Total
# 0             UPI      A   2340
# 1     Net Banking      B   2500
# 2     Credit Card      B   9440
# 3            Cash      C  19050
# 4            Cash      B   4152
# ..            ...    ...    ...
# 495           UPI      C   1025
# 496   Net Banking      B   4002
# 497          Cash      B  30590
# 498   Net Banking      B    203
# 499   Credit Card      B   7605
#
# [500 rows x 8 columns]

# %%
import pandas as pd
df = pd.read_csv('/content/product_sales_500.csv')
df.drop('Date',axis=1, inplace=True)
print(df)
# Out:
#     InvoiceID     Product  UnitPrice  Quantity PaymentMethod Branch  Total
# 0     INV1000       Mouse        390         6           UPI      A   2340
# 1     INV1001     Charger       2500         1   Net Banking      B   2500
# 2     INV1002     Monitor       1180         8   Credit Card      B   9440
# 3     INV1003       Mouse       3175         6          Cash      C  19050
# 4     INV1004  Headphones       1384         3          Cash      B   4152
# ..        ...         ...        ...       ...           ...    ...    ...
# 495   INV1495       Mouse        205         5           UPI      C   1025
# 496   INV1496  Headphones        667         6   Net Banking      B   4002
# 497   INV1497     Charger       4370         7          Cash      B  30590
# 498   INV1498      Laptop        203         1   Net Banking      B    203
# 499   INV1499     Charger        845         9   Credit Card      B   7605
#
# [500 rows x 7 columns]

# %%
Products=df.groupby(['Product','PaymentMethod'])
Products

# %%
len(df)
# Out:
# 500

# %%
len(Products)
# Out:
# 32

# %%
new_Products=Products.get_group(('Laptop','UPI'))
new_Products
# Out:
#     InvoiceID Product  UnitPrice  Quantity PaymentMethod Branch  Total
# 31    INV1031  Laptop       3150         2           UPI      A   6300
# 192   INV1192  Laptop       3777         7           UPI      A  26439
# 247   INV1247  Laptop        655         1           UPI      A    655
# 251   INV1251  Laptop       3272         8           UPI      C  26176
# 278   INV1278  Laptop       3530         5           UPI      B  17650
# 292   INV1292  Laptop        739         2           UPI      A   1478
# 330   INV1330  Laptop       3836         5           UPI      C  19180
# 351   INV1351  Laptop       1277         5           UPI      A   6385
# 399   INV1399  Laptop       3466         9           UPI      B  31194
# 413   INV1413  Laptop       3317         7           UPI      A  23219
# 415   INV1415  Laptop       2168         4           UPI      C   8672
# 430   INV1430  Laptop        838         8           UPI      B   6704
# 442   INV1442  Laptop       1731         2           UPI      B   3462
# 463   INV1463  Laptop       1693         9           UPI      B  15237
# 467   INV1467  Laptop       2860         1           UPI      B   2860

# %%
new_Products.size
# Out:
# 105

# %%
new_Products.head(1)
# Out:
#    InvoiceID Product  UnitPrice  Quantity PaymentMethod Branch  Total
# 31   INV1031  Laptop       3150         2           UPI      A   6300

# %%
Products.groups
df.iloc[24,:]
# Out:
# InvoiceID            INV1024
# Product              Charger
# UnitPrice               3375
# Quantity                   6
# PaymentMethod    Credit Card
# Branch                     B
# Total                  20250
# Name: 24, dtype: object

# %%
Products.get_group('Charger')
# Out:
#     InvoiceID  Product  UnitPrice  Quantity PaymentMethod Branch  Total
# 1     INV1001  Charger       2500         1   Net Banking      B   2500
# 16    INV1016  Charger       3101         4   Credit Card      A  12404
# 24    INV1024  Charger       3375         6   Credit Card      B  20250
# 29    INV1029  Charger       2655         2   Net Banking      A   5310
# 32    INV1032  Charger       4331         4   Net Banking      A  17324
# ..        ...      ...        ...       ...           ...    ...    ...
# 479   INV1479  Charger       2524         7          Cash      C  17668
# 480   INV1480  Charger       1933         4           UPI      B   7732
# 487   INV1487  Charger       3070         2   Net Banking      B   6140
# 497   INV1497  Charger       4370         7          Cash      B  30590
# 499   INV1499  Charger        845         9   Credit Card      B   7605
#
# [76 rows x 7 columns]

# %%
Products.mean(numeric_only=True)
# Out:
#               UnitPrice  Quantity         Total
# Product
# Charger     2814.526316  5.434211  14734.500000
# Headphones  2589.984375  3.953125  10100.328125
# Keyboard    2842.612903  4.838710  13682.096774
# Laptop      2593.084507  5.492958  15237.338028
# Mobile      2680.000000  4.413043  10799.608696
# Monitor     2445.137255  5.235294  11695.941176
# Mouse       2778.206897  5.655172  15927.448276
# Smartwatch  2639.083333  4.625000  12597.569444

# %%
Products['Quantity'].mean().sort_values(ascending=False)
# Out:
# Product
# Mouse         5.655172
# Laptop        5.492958
# Charger       5.434211
# Monitor       5.235294
# Keyboard      4.838710
# Smartwatch    4.625000
# Mobile        4.413043
# Headphones    3.953125
# Name: Quantity, dtype: float64
